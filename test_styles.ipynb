# %%
import nb_style
nb_style.apply()
# Out:
#     <style>
#
#     /* ===== COURSE HEADER ===== */
#
#     .course-header {
#         width: 100%;
#         box-sizing: border-box;
#         background: #FAEEEB;
#         color: #2c3e50;
#         padding: 12px 18px;
#         margin-bottom: 20px;
#         border-radius: 8px;
#         border: 1px solid #ead9d4;
#
#         position: relative;
#         display: flex;
#         align-items: center;
#         justify-content: center;
#
#         font-family: Calibri, sans-serif;
#         min-height: 120px;
#     }
#
#     .course-header img {
#         position: absolute;
#         left: 18px;
#         top: 50%;
#         transform: translateY(-50%);
#         height: 120px;
#         width: auto;
#     }
#
#     .course-header-text {
#         text-align: center;
#         line-height: 1.2;
#     }
#
#     .course-title {
#         font-size: 32px;
#         font-weight: bold;
#         margin: 0;
#     }
#
#     .course-author {
#         font-size: 18px;
# ...

# %% [markdown]
# # Notebook Theme Demonstration
#
# This paragraph shows the **base font, color, width, and spacing** of the markdown body.
# Notice how the text is centered and does not stretch across the full screen.
#
# ---
#
# ## Section Heading (H2)
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit.
# Vestibulum feugiat ligula sit amet sem interdum, sed facilisis purus posuere.
#
# Another paragraph to show **vertical spacing between paragraphs**.
# This is important for readability in lecture notes.
#
# ---
#
# ### Subsection Heading (H3)
#
# You can use smaller headings to structure explanations.
#
# - Bullet list item one
# - Bullet list item two
# - Bullet list item three
#
# 1. Numbered item one
# 2. Numbered item two
# 3. Numbered item three
#
# ---
#
# ## Blockquote / Callout Example
#
# > Important: This blockquote is styled as a **callout box**.
# > You can use it for definitions, warnings, remarks, or key ideas.
#
# > Tip: Students visually recognize this as important content.
#
# ---
#
# ## Inline Code Example
#
# You can refer to variables like `learning_rate`, `x_train`, or functions like `fit_model()`.
#
# ---
#
# ## Math Example
#
# Inline math: $E = mc^2$
#
# Display math:
#
# $$
# \nabla f(x) = \left(
# \frac{\partial f}{\partial x_1},
# \frac{\partial f}{\partial x_2}
# \right)
# $$
#
# ---
#
# ## Table Example
#
# | Method | Accuracy | Time (s) |
# |--------|----------|---------|
# | Gradient Descent | 0.91 | 2.3 |
# | Newton Method | 0.95 | 1.1 |
# | SGD | 0.88 | 0.6 |
#
# ---
#
# ## Long Text Width Demonstration
#
# This is a longer paragraph meant to show the **maximum content width setting**.
# Because the layout is constrained to about 860px and centered automatically,
# the notebook reads more like an article or textbook instead of a stretched code editor.
#
# This greatly improves reading comfort during lectures or self-study.
#
# ---
#
# ## Nested Blockquote
#
# > Definition
# >
# > A function $f$ is **convex** if for all $x, y$ and $\lambda \in [0,1]$:
# >
# > $$
# > f(\lambda x + (1-\lambda)y) \le \lambda f(x) + (1-\lambda)f(y)
# > $$
#
# ---
#
# ### End of Demonstration
